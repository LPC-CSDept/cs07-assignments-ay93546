# %%
coordinate = input("Enter coordinates like 'x, y':")
x, y = coordinate.split(',')
x = int(x)
y = int(y)
if x > 0:
  if y > 0:
    print("Quadrant 1")
  else:
    print("Quadrant 4")
else:
  if y > 0:
    print("Quadrant 2")
  else:
    print("Quadrant 3")
# Out:
# Quadrant 1
