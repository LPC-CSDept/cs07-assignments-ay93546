# %%
import random
a = random.randint(0, 100)
b = random.randint(0, 100)
c = random.randint(0, 100)
if a < b:
  if a < c:
    lowest_number = a
  else:
    lowest_number = c
else:
  if b < c:
    lowest_number = b
  else:
    lowest_number = c

print(a, b, c)
print(lowest_number)
# Out:
# 91 38 33
# 33
