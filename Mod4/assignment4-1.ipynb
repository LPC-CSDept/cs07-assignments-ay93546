# %%
for i in range(1,11):
  print(2 ** i, end = ' ')
# Out:
# 2 4 8 16 32 64 128 256 512 1024

# %%
sum = 0
for i in range(5):
  user_num = int(input("Enter number: "))
  sum += user_num
print("Sum:", sum)
# Out:
# Sum: 15

# %%
sum = 0
count = 0
while count < 5:
  user_num = int(input("Enter number: "))
  sum += user_num
  count += 1
print("Sum:", sum)
# Out:
# Sum: 15
